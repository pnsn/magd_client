# %% [markdown]
# # Noise Study to look at detection thresholds with and without analog EHZ channels

# %% [markdown]
# ## SQL querries for UW, UO, and CC

# %% [markdown]
# ### 4 channel stations with EHZ and ENZ or HNZ

# %% [markdown]
# ``` psql -h $AWS_POSTGRES_SERVER  -d pnsn_web_production -c "\copy (select c1.sta, c1.seedchan, c1.net, c1.location from channels c1, channels c2  where c1.net in ('UW','UO','CC') and c1.sta=c2.sta and c1.seedchan='EHZ' and c2.seedchan in  ('ENZ','HNZ')) to '~/4_component.csv' WITH (FORMAT CSV, HEADER TRUE, FORCE_QUOTE *);"```

# %% [markdown]
# ### All Broadband

# %% [markdown]
# ``` psql -h $AWS_POSTGRES_SERVER  -d pnsn_web_production -c "\copy (select sta, seedchan, net, location from channels  where net in ('UW','UO','CC') and  seedchan in  ('BHZ','HHZ')) to '~/all_bb.csv' WITH (FORMAT CSV, HEADER TRUE, FORCE_QUOTE *);"```

# %% [markdown]
# ###  EHZ  with ENZ or HNZ

# %% [markdown]
# ```psql -h $AWS_POSTGRES_SERVER  -d pnsn_web_production -c "\copy (select sta, seedchan, net, location from channels  where net in ('UW','UO','CC') and  seedchan ='EHZ') to '~/ehz.csv' WITH (FORMAT CSV, HEADER TRUE, FORCE_QUOTE *);" ```

# %% [markdown]
# ## Query FDSN using above CSV and output CSV with location and samprate

# %%
import os; os.chdir('/Users/joncon/Sites/magd_client/')

# %%
# %run -i magD/make_csv.py -i csv/2017_EHZ_study/all_bb.csv -o csv/2017_EHZ_study/all_bb_fdsn.csv

# %%
# %run -i magD/make_csv.py -i csv/2017_EHZ_study/ehz.csv -o csv/2017_EHZ_study/ehz_fdsn.csv
# Out:
# Query for BLJ:EHZ:UW:-- failed with:HTTP Error 404: Not Found

# %%
# %run -i magD/make_csv.py -i csv/2017_EHZ_study/4_component.csv -o csv/2017_EHZ_study/4_component_fdsn.csv

# %% [markdown]
# ## Create and save MapGrids

# %% [markdown]
# ### Ran at following commit levels
# MagD commit https://github.com/pnsn/magD/commit/ff3887ad0af278322eff6cb924a40a8e4c89a29d
#
# magd_client commit https://github.com/pnsn/magd_client/commit/9d218b9d0b3788f3d2414c9a2194ffa9b3f23f30

# %%
 # %run -i scripts/make_ehz_grids.py config/ehz_profile/ehz_and_bb.ini

# %%
 # %run -i scripts/make_ehz_grids.py config/ehz_profile/no_rack.ini
# Out:
# UGAP2:EHZ:--:UW startime: 2017-01-01, endtime 2018-01-01 returned HTTP code 404
# UGAP3:EHZ:--:UW startime: 2017-01-01, endtime 2018-01-01 returned HTTP code 404
# 2 channel(s) found without noise pdf

# %% [markdown]
# ## Detection Maps

# %%
# %matplotlib inline

# %% [markdown]
# ### Detection Run 1: BB and Digital SP
# All UW,UO,CC Broadbands and Short Periods
#
# This scenerio shows detection threshold with all Broadband and short periods

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/detection_grid/ehz_and_bb-139x151-res-0.1.pickle \
--title='Magnitude Detection Thresholds' \
--description='All Broadband and Short Period' \
--color=viridis \
--plot_max=3 \
--plot_min=-1

# %% [markdown]
# ### Detection Run 2: Run BB and Digital SP
# All UW,UO,CC Broadbands and Digitized Short Periods
#
# This scenerio shows detection threshold minus the analog rack

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/detection_grid/4chan_ehz_bb-139x151-res-0.1.pickle \
--title='Magnitude Detection Thresholds' \
--description='All Broadband and Digial Short Period' \
--color=viridis \
--plot_max=3 \
--plot_min=-1

# %% [markdown]
# ### Detection Run 3: Diff after removing all SP
# Increase in detection after removing analog short period stations (rack)

# %% [markdown]
# Instantiate both grids, clone one grid and then set clones grid to diff of other two

# %%
grid_all=get_pickle('./pickle_jar/detection_grid/ehz_and_bb-139x151-res-0.1.pickle')

# %%
grid_no_rack=get_pickle('./pickle_jar/detection_grid/4chan_ehz_bb-139x151-res-0.1.pickle')

# %%
grid_diff=grid_all.copy("all_diff_no_rack", "all_diff_no_rack")

# %%
grid_diff.matrix=grid_no_rack.matrix - grid_all.matrix

# %%
grid_diff.save()

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/all_diff_no_rack_grid/all_diff_no_rack-139x151-res-0.1.pickle \
--title='Difference in Detection Thresholds' \
--description='By Removing all Analaog Short Periods' \
--color=viridis

# %% [markdown]
# ## Azimuthal Gap Plot

# %% [markdown]
# Azimuthal Gap using the five stations that contributed to the solution

# %% [markdown]
# ### Run 1 All BB and SP

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/gap_grid/ehz_and_bb-139x151-res-0.1.pickle \
--title='Azimuthal Gap of all BB and SP' \
--description='That contributed to solution ' \
--color=Blues \

# %% [markdown]
# ## Distance Plots

# %% [markdown]
# Distances to contributing stations

# %% [markdown]
# ### Run1 Closest Contributing Station

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/dist_min_grid/ehz_and_bb-139x151-res-0.1.pickle \
--title='Distance to nearest station' \
--description='That contributed to solution ' \
--color=Blues \
--plot_max=1000 \
--plot_min=0

# %% [markdown]
# ### Run2:  Median Contributing Station

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/dist_med_grid/ehz_and_bb-139x151-res-0.1.pickle \
--title='Distance to median station' \
--description='That contributed to solution ' \
--color=Blues \
--plot_max=1000 \
--plot_min=0

# %% [markdown]
# ### Run 3: Average Distance of Contributing Stations

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/dist_ave_grid/ehz_and_bb-139x151-res-0.1.pickle \
--title='Distance to nearest station' \
--description='That contributed to solution ' \
--color=Blues \
--plot_max=1000 \
--plot_min=0

# %% [markdown]
# ### Run 4: Furthest Contributing Station

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/dist_max_grid/ehz_and_bb-139x151-res-0.1.pickle \
--title='Distance to furthest station' \
--description='That contributed to solution ' \
--color=Blues \
--plot_max=1000 \
--plot_min=0

# %% [markdown]
# ## Azimuthal Gap and Distance

# %% [markdown]
# Combining Azimuthal Gap and Distance

# %% [markdown]
# ### Run1 Gap + Closest Contributing Station

# %%
grid_gap=get_pickle('./pickle_jar/gap_grid/ehz_and_bb-139x151-res-0.1.pickle')

# %%
grid_dist_min=get_pickle('./pickle_jar/dist_min_grid/ehz_and_bb-139x151-res-0.1.pickle')

# %%
grid_gap_dist_min=grid_gap.copy("gap_dist_min", "gap_dist_min")

# %% [markdown]
# Take log distance then normalize, add to normalized gap

# %%
grid_gap_dist_min.matrix =  0.5*(np.log(grid_dist_min.matrix)/np.log(np.max(grid_dist_min.matrix)) + \
    grid_gap.matrix/np.max(grid_gap.matrix))

# %%
grid_gap_dist_min.save()

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/gap_dist_min_grid/gap_dist_min-139x151-res-0.1.pickle \
--title='Gap and Distance to closet station' \
--description='that contributed to solution ' \
--color=Blues \
--plot_max=1 \
--plot_min=0

# %% [markdown]
# ### Run 2: Gap + Median Contributing Station

# %%
grid_dist_med=get_pickle('./pickle_jar/dist_med_grid/ehz_and_bb-139x151-res-0.1.pickle')

# %%
grid_gap_dist_med=grid_gap.copy("gap_dist_med", "gap_dist_med")

# %% [markdown]
# Take log distance then normalize, add to normalized gap

# %%
grid_gap_dist_med.matrix =  0.5*(np.log(grid_dist_med.matrix)/np.log(np.max(grid_dist_med.matrix)) + \
    grid_gap.matrix/np.max(grid_gap.matrix))

# %%
grid_gap_dist_med.save()

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/gap_dist_med_grid/gap_dist_med-139x151-res-0.1.pickle \
--title='Gap and Distance to median station' \
--description='that contributed to solution ' \
--color=Blues \
--plot_max=1 \
--plot_min=0

# %% [markdown]
# ### Run 3: Gap + Ave Contributing Station

# %%
grid_dist_ave=get_pickle('./pickle_jar/dist_ave_grid/ehz_and_bb-139x151-res-0.1.pickle')

# %%
grid_gap_dist_ave=grid_gap.copy("gap_dist_ave", "gap_dist_ave")

# %% [markdown]
# Take log distance then normalize, add to normalized gap

# %%
grid_gap_dist_ave.matrix =  0.5*(np.log(grid_dist_ave.matrix)/np.log(np.max(grid_dist_ave.matrix)) + \
    grid_gap.matrix/np.max(grid_gap.matrix))

# %%
grid_gap_dist_ave.save()

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/gap_dist_ave_grid/gap_dist_ave-139x151-res-0.1.pickle \
--title='Gap and Distance to ave station' \
--description='that contributed to solution ' \
--color=Blues \
--plot_max=1 \
--plot_min=0

# %% [markdown]
# ### Run 4: Gap + Max Contributing Station

# %%
grid_dist_max=get_pickle('./pickle_jar/dist_max_grid/ehz_and_bb-139x151-res-0.1.pickle')

# %%
grid_gap_dist_max=grid_gap.copy("gap_dist_max", "gap_dist_max")

# %% [markdown]
# Take log distance then normalize, add to normalized gap

# %%
grid_gap_dist_max.matrix =  0.5*(np.log(grid_dist_max.matrix)/np.log(np.max(grid_dist_max.matrix)) + \
    grid_gap.matrix/np.max(grid_gap.matrix))

# %%
grid_gap_dist_max.save()

# %%
# %run -i scripts/plot_ehz_profile.py \
--path pickle_jar/gap_dist_max_grid/gap_dist_max-139x151-res-0.1.pickle \
--title='Gap and Distance to furthest station' \
--description='that contributed to solution ' \
--color=Blues \
--plot_max=1 \
--plot_min=0
