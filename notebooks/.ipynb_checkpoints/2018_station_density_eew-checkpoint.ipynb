# %% [markdown]
# # Station Density Profile of Westcoast Earthquake Early Warning Stations

# %% [markdown]
# ## Create csv of all EEW sites

# %% [markdown]
# Must have the following headers:
# * net
# * sta
# * chan
# * location
# * lat
# * lon
# * rate*
#
# *sample rate(not required)

# %%
import os; os.chdir('/Users/joncon/Sites/magd_client/')
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Create and save MapGrids

# %% [markdown]
# ### Ran at following commit levels
# MagD commit c3da89defd399caf8e5333bb22f4978bc37d112b
#
# magd_client commit 0812d1b4316f731a90fd35215735098d05ae556f

# %%
 # %run -i scripts/make_grids.py config/eew_density
# Out:
# Profiling spatially...

# %%
# %run -i scripts/plot_heatmap.py \
--path=pickle_jar/eew_all_density/dist_max_grid/eew_all_density-249x191-res-0.1.pickle \
--title1="EEW Station Density" \
--title2="All Current West Coast Stations" \
--title3="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--levels=0,0.1,10,40

# %%
# %run -i scripts/plot_heatmap.py \
--path=pickle_jar/eew_all_density/dist_max_grid/eew_all_density-249x191-res-0.1.pickle \
--title1="EEW Blindzone. 8Km Depth" \
--title2="All Current West Coast Stations" \
--title3="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--depth=8 \
--velocity_p=8 \
--velocity_s=5 \
--levels=0,0.1,10,40

# %%
# %run -i scripts/plot_heatmap.py \
--path=pickle_jar/eew_all_density/dist_max_grid/eew_all_density-249x191-res-0.1.pickle \
--title1="EEW Blindzone. 20Km Depth" \
--title2="All Current West Coast Stations" \
--title3="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--depth=20 \
--velocity_p=8 \
--velocity_s=5 \
--levels=0,0.1,10,40

# %%
# %run -i scripts/plot_heatmap.py \
--path=pickle_jar/eew_all_density/dist_max_grid/eew_all_density-249x191-res-0.1.pickle \
--title1="EEW Blindzone. 50Km Depth" \
--title2="All Current West Coast Stations" \
--title3="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--depth=50 \
--velocity_p=8 \
--velocity_s=5 \
--levels=0,0.1,10,40
