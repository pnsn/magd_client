# %% [markdown]
# # Station Density Profile of Washington Earthquake Early Warning Stations

# %% [markdown]
# ## Create csv of all EEW sites

# %% [markdown]
# Must have the following headers:
# * net
# * sta
# * chan
# * location
# * lat
# * lon
# * rate*
#
# *sample rate(not required)

# %% [markdown]
# ## Clean CSV

# %% [markdown]
# ### Ran at following commit levels
# MagD commit
#
# magd_client commit

# %% [markdown]
# Remove duplicate stations since we are only concerned with spatial location

# %%
# %run scripts/clean_csv.py -i csv/eew_density/eew_stas_current_all.csv -o csv/eew_density/eew_stas_current_clean.csv

# %% [markdown]
#  ## Current and notional station density Depth=0

# %%
import os; os.chdir('/Users/joncon/Sites/magd_client/')
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### Current Stations Grid

# %%
 # %run -i scripts/make_grids.py config/eew_washington/current
# Out:
# Profiling spatially...
# Created the following grids:
# /Users/joncon/Sites/magd_client/pickle_jar/eew_current_all/dist_max_grid/eew_current_all-84x121-res-0.1.pickle

# %%
grid_current_path = "./pickle_jar/eew_current_all/dist_max_grid/eew_current_all-84x121-res-0.1.pickle"
grid_current = get_pickle(grid_current_path)

# %%
# %run -i scripts/plot_heatmap.py \
--path=$grid_current_path \
--title1="Washington EEW Station Density" \
--title2="All Current Washington Stations" \
--title3="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--plotwidth=10 \
--plotheight=12 \
--plotstas=True \
--levels=0,10,20,30,40

# %% [markdown]
# ### Current and Notitional Grid

# %%
 # %run -i scripts/make_grids.py config/eew_washington/current_and_notional
# Out:
# Profiling spatially...
# Created the following grids:
# /Users/joncon/Sites/magd_client/pickle_jar/eew_curent_and_notional/dist_max_grid/eew_curent_and_notional-84x121-res-0.1.pickle

# %%
grid_notional_path='./pickle_jar/eew_curent_and_notional/dist_max_grid/eew_curent_and_notional-84x121-res-0.1.pickle'
grid_notional = get_pickle(grid_notional_path)

# %%
# %run -i scripts/plot_heatmap.py \
--path=$grid_notional_path \
--title1="Washington EEW Station Density" \
--title2="All Current and Notional Washington Stations" \
--title3="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--plotwidth=10 \
--plotheight=12 \
--plotstas=True \
--levels=0,10,20,30,40

# %% [markdown]
# ### Diff of Current and Notional

# %%
grid_diff_0 = grid_notional.copy("diff_0", "diff_0")
grid_diff_0.matrix = grid_current.matrix - grid_notional.matrix
grid_diff_0.save()
print(grid_diff_0.get_path())
# Out:
# /Users/joncon/Sites/magd_client/pickle_jar/diff_0/diff_0_grid/diff_0-84x121-res-0.1.pickle

# %%
grid_diff_0_path="./pickle_jar/diff_0/diff_0_grid/diff_0-84x121-res-0.1.pickle"

# %%
# %run -i scripts/plot_heatmap.py \
--path=$grid_diff_0_path \
--title1="Washington EEW Station Density" \
--title2="Notional difference Washington Stations" \
--title3="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--plotwidth=10 \
--plotheight=12 \
--plotstas=True \
--levels=0.1,10,20,30,40

# %% [markdown]
# ## Blind zone

# %%
velocity_p = 5.4
velocity_s = 3

# %% [markdown]
# ### 8km Depth

# %%
grid_dist_max = get_pickle('./pickle_jar/eew_washington_density/dist_max_grid/eew_washington_density-89x121-res-0.1.pickle')

grid_blindzone8 = grid_dist_max.copy("blindzone", "grid_blindzone8")

grid_blindzone8.transform_to_blindzone(velocity_p, velocity_s, 8)

grid_blindzone8.save()

path = grid_blindzone8.get_path()

# %%
# %run -i scripts/plot_heatmap.py \
--path=pickle_jar/grid_blindzone8/blindzone_grid/grid_blindzone8-89x121-res-0.1.pickle \
--title1="Washington EEW Blindzone. 8Km Depth" \
--title2="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--levels=0,0.1,10,40
# Out:
# 47.05
# -120.95

# %%
velocity_p = 8
velocity_s = 5

grid_dist_max = get_pickle('./pickle_jar/eew_washington_density/dist_max_grid/eew_washington_density-89x121-res-0.1.pickle')

grid_blindzone20 = grid_dist_max.copy("blindzone", "grid_blindzone20")

grid_blindzone20.transform_to_blindzone(velocity_p, velocity_s, 20)

grid_blindzone20.save()

print(grid_blindzone20.get_path())
# Out:
# /Users/joncon/Sites/magd_client/pickle_jar/grid_blindzone20/blindzone_grid/grid_blindzone20-89x121-res-0.1.pickle

# %%
# %run -i scripts/plot_heatmap.py \
--path=pickle_jar/grid_blindzone20/blindzone_grid/grid_blindzone20-89x121-res-0.1.pickle \
--title1="Washington EEW Blindzone. 20Km Depth" \
--title2="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--depth=20 \
--velocity_p=8 \
--velocity_s=5 \
--levels=0,0.1,10,40
# Out:
# 47.05
# -120.95

# %%
velocity_p = 8
velocity_s = 5

grid_dist_max = get_pickle('./pickle_jar/eew_washington_density/dist_max_grid/eew_washington_density-89x121-res-0.1.pickle')

grid_blindzone50 = grid_dist_max.copy("blindzone", "grid_blindzone50")

grid_blindzone50.transform_to_blindzone(velocity_p, velocity_s, 50)

grid_blindzone50.save()

print(grid_blindzone50.get_path())
# Out:
# /Users/joncon/Sites/magd_client/pickle_jar/grid_blindzone50/blindzone_grid/grid_blindzone50-89x121-res-0.1.pickle

# %%
# %run -i scripts/plot_heatmap.py \
--path=pickle_jar/grid_blindzone50/blindzone_grid/grid_blindzone50-89x121-res-0.1.pickle \
--title1="Washington EEW Blindzone. 50Km Depth" \
--title2="4th closet station 0.1 deg resolution" \
--color=viridis_r \
--depth=50 \
--velocity_p=8 \
--velocity_s=5 \
--levels=0,0.1,10,40
# Out:
# 47.05
# -120.95
